# %% [markdown]
# <a href="https://colab.research.google.com/github/catfoodlover/msdsrepo/blob/main/DATA602HW6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df1 = pd.read_csv('https://raw.githubusercontent.com/data602sps/datasetspractice/main/weather.csv')

# %% [markdown]
# We use the columns method to look at the names of the dataframe.  We can tell that this a dataset related to weather
#
# We can call the dataframe and it prints out the first 5 and last 5 rows.  We can see that the dataframe is 8719 rows × 15 columns

# %%
print(df1.columns)


df1
# Out:
# Index(['Unnamed: 0', 'origin', 'year', 'month', 'day', 'hour', 'temp', 'dewp',
#        'humid', 'wind_dir', 'wind_speed', 'wind_gust', 'precip', 'pressure',
#        'visib'],
#       dtype='object')
#       Unnamed: 0 origin  year  month   day  hour   temp   dewp  humid  \
# 0              1    EWR  2013    1.0   1.0   0.0  37.04  21.92  53.97
# 1              2    EWR  2013    1.0   1.0   1.0  37.04  21.92  53.97
# 2              3    EWR  2013    1.0   1.0   2.0  37.94  21.92  52.09
# 3              4    EWR  2013    1.0   1.0   3.0  37.94  23.00  54.51
# 4              5    EWR  2013    1.0   1.0   4.0  37.94  24.08  57.04
# ...          ...    ...   ...    ...   ...   ...    ...    ...    ...
# 8714        8715    JFK  2013    9.0   2.0  20.0  75.20  73.40  94.14
# 8715        8716    JFK  2013   10.0  23.0  10.0  48.92  39.02  68.51
# 8716        8717    JFK  2013   10.0  23.0  11.0  48.92  39.02  68.51
# 8717        8718    JFK  2013   12.0  17.0   5.0  26.96  10.94  50.34
# ...

# %% [markdown]
# Shape shows us that this dataframe is 8719 X 15

# %%
df1.shape
# Out:
# (8719, 15)

# %% [markdown]
# We can see that most of the columns are of type float which is helpful for future manipulation

# %%
df1.dtypes
# Out:
# Unnamed: 0      int64
# origin         object
# year            int64
# month         float64
# day           float64
# hour          float64
# temp          float64
# dewp          float64
# humid         float64
# wind_dir      float64
# wind_speed    float64
# wind_gust     float64
# precip        float64
# pressure      float64
# visib         float64
# dtype: object

# %% [markdown]
# This shows us the dimensions, column names and top 5 and bottom 5 rows.

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of       Unnamed: 0 origin  year  month   day  hour   temp   dewp  humid  \
# 0              1    EWR  2013    1.0   1.0   0.0  37.04  21.92  53.97
# 1              2    EWR  2013    1.0   1.0   1.0  37.04  21.92  53.97
# 2              3    EWR  2013    1.0   1.0   2.0  37.94  21.92  52.09
# 3              4    EWR  2013    1.0   1.0   3.0  37.94  23.00  54.51
# 4              5    EWR  2013    1.0   1.0   4.0  37.94  24.08  57.04
# ...          ...    ...   ...    ...   ...   ...    ...    ...    ...
# 8714        8715    JFK  2013    9.0   2.0  20.0  75.20  73.40  94.14
# 8715        8716    JFK  2013   10.0  23.0  10.0  48.92  39.02  68.51
# 8716        8717    JFK  2013   10.0  23.0  11.0  48.92  39.02  68.51
# 8717        8718    JFK  2013   12.0  17.0   5.0  26.96  10.94  50.34
# 8718        8719    LGA  2013    8.0  22.0  22.0  75.92  66.92  73.68
#
#       wind_dir  wind_speed  wind_gust  precip  pressure  visib
# ...

# %% [markdown]
# Head shows us the top 5 rows and column names

# %%
df1.head()
# Out:
#    Unnamed: 0 origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0           1    EWR  2013    1.0  1.0   0.0  37.04  21.92  53.97     230.0
# 1           2    EWR  2013    1.0  1.0   1.0  37.04  21.92  53.97     230.0
# 2           3    EWR  2013    1.0  1.0   2.0  37.94  21.92  52.09     230.0
# 3           4    EWR  2013    1.0  1.0   3.0  37.94  23.00  54.51     230.0
# 4           5    EWR  2013    1.0  1.0   4.0  37.94  24.08  57.04     240.0
#
#    wind_speed  wind_gust  precip  pressure  visib
# 0    10.35702  11.918651     0.0    1013.9   10.0
# 1    13.80936  15.891535     0.0    1013.0   10.0
# 2    12.65858  14.567241     0.0    1012.6   10.0
# 3    13.80936  15.891535     0.0    1012.7   10.0
# 4    14.96014  17.215830     0.0    1012.8   10.0

# %% [markdown]
# This is less helpful

# %%
df1.tail()
# Out:
#       Unnamed: 0 origin  year  month   day  hour   temp   dewp  humid  \
# 8714        8715    JFK  2013    9.0   2.0  20.0  75.20  73.40  94.14
# 8715        8716    JFK  2013   10.0  23.0  10.0  48.92  39.02  68.51
# 8716        8717    JFK  2013   10.0  23.0  11.0  48.92  39.02  68.51
# 8717        8718    JFK  2013   12.0  17.0   5.0  26.96  10.94  50.34
# 8718        8719    LGA  2013    8.0  22.0  22.0  75.92  66.92  73.68
#
#       wind_dir  wind_speed  wind_gust  precip  pressure  visib
# 8714     200.0     4.60312   5.297178     0.0       NaN    4.0
# 8715      60.0     4.60312   5.297178     0.0    1008.1   10.0
# 8716      40.0     4.60312   5.297178     0.0    1008.5   10.0
# 8717      40.0     4.60312   5.297178     0.0    1023.9   10.0
# 8718     210.0     8.05546   9.270062     0.0    1011.9   10.0

# %% [markdown]
# Here we are reading in the salary dataset

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/data602sps/datasetspractice/main/salarydata.csv')

# %% [markdown]
# Our columns are 'State',2018 Mean Annual Wage', 'Unnamed: 2'.  We are going to have to remove the last column.  It's unnamed and empty.

# %%
print(df2.columns)


df2
# Out:
# Index(['Sate ', '2018 Mean Annual Wage', 'Unnamed: 2'], dtype='object')
#                    Sate  2018 Mean Annual Wage  Unnamed: 2
# 0               Alabama                 90,620         NaN
# 1                 Alaska                99,180         NaN
# 2                Arizona                88,800         NaN
# 3               Arkansas                81,430         NaN
# 4             California                97,110         NaN
# 5               Colorado                82,560         NaN
# 6            Connecticut                96,010         NaN
# 7               Delaware                93,880         NaN
# 8   District of Columbia                89,880         NaN
# 9                Florida                87,410         NaN
# 10               Georgia                86,320         NaN
# 11                Hawaii                90,540         NaN
# 12                 Idaho                77,700         NaN
# 13              IIIinois                90,690         NaN
# ...

# %% [markdown]
# This dataset is 51 X 3

# %%
df2.shape
# Out:
# (51, 3)

# %% [markdown]
# Looking at the datatype is helpful, something is going on with this dataset.  Why is the wage column type object and the unnamed column is type float?

# %%
df2.dtypes
# Out:
# Sate                      object
# 2018 Mean Annual Wage     object
# Unnamed: 2               float64
# dtype: object

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of                    Sate  2018 Mean Annual Wage  Unnamed: 2
# 0               Alabama                 90,620         NaN
# 1                 Alaska                99,180         NaN
# 2                Arizona                88,800         NaN
# 3               Arkansas                81,430         NaN
# 4             California                97,110         NaN
# 5               Colorado                82,560         NaN
# 6            Connecticut                96,010         NaN
# 7               Delaware                93,880         NaN
# 8   District of Columbia                89,880         NaN
# 9                Florida                87,410         NaN
# 10               Georgia                86,320         NaN
# 11                Hawaii                90,540         NaN
# 12                 Idaho                77,700         NaN
# 13              IIIinois                90,690         NaN
# ...

# %%
df2.head()
# Out:
#         Sate  2018 Mean Annual Wage  Unnamed: 2
# 0    Alabama                 90,620         NaN
# 1      Alaska                99,180         NaN
# 2     Arizona                88,800         NaN
# 3    Arkansas                81,430         NaN
# 4  California                97,110         NaN

# %%
df2.tail()
# Out:
#             Sate  2018 Mean Annual Wage  Unnamed: 2
# 46       Virginia                91,700         NaN
# 47     Washington                85,930         NaN
# 48  West Virginia                89,420         NaN
# 49      Wisconsin                85,200         NaN
# 50        Wyomimg                87,510         NaN

# %% [markdown]
# This a monster dataset of New York City Regents Test Scores

# %%
df3 = pd.read_excel('https://data.cityofnewyork.us/api/views/365g-7jtb/files/17910cb0-8a62-4037-84b5-f0b4c2b3f71f?download=true&filename=school-math-results-2013-2019-(public).xlsx')

# %%
print(df3.columns)
# Out:
# Index(['Unnamed: 0', 'DBN', 'School Name', 'Grade', 'Year', 'Category',
#        'Number Tested', 'Mean Scale Score', '# Level 1', '% Level 1',
#        '# Level 2', '% Level 2', '# Level 3', '% Level 3', '# Level 4',
#        '% Level 4', '# Level 3+4', '% Level 3+4'],
#       dtype='object')

# %%
df3
# Out:
#                              Unnamed: 0     DBN  \
# 0               01M01532013All Students  01M015
# 1               01M01532014All Students  01M015
# 2               01M01532015All Students  01M015
# 3               01M01532016All Students  01M015
# 4               01M01532017All Students  01M015
# ...                                 ...     ...
# 32601  32K562All Grades2015All Students  32K562
# 32602  32K562All Grades2016All Students  32K562
# 32603  32K562All Grades2017All Students  32K562
# 32604  32K562All Grades2018All Students  32K562
# 32605  32K562All Grades2019All Students  32K562
#
#                                          School Name       Grade  Year  \
# 0                          P.S. 015 ROBERTO CLEMENTE           3  2013
# 1                          P.S. 015 ROBERTO CLEMENTE           3  2014
# 2                          P.S. 015 ROBERTO CLEMENTE           3  2015
# 3                          P.S. 015 ROBERTO CLEMENTE           3  2016
# ...

# %% [markdown]
# This datasets it 32606 X 18

# %%
df3.shape
# Out:
# (32606, 18)

# %% [markdown]
# Most of these columns are type object meaning we will have to convert them to perform any operations on them

# %%
df3.dtypes
# Out:
# Unnamed: 0          object
# DBN                 object
# School Name         object
# Grade               object
# Year                 int64
# Category            object
# Number Tested        int64
# Mean Scale Score    object
# # Level 1           object
# % Level 1           object
# # Level 2           object
# % Level 2           object
# # Level 3           object
# % Level 3           object
# # Level 4           object
# % Level 4           object
# # Level 3+4         object
# % Level 3+4         object
# dtype: object

# %% [markdown]
# The describe method isn't ideal for columns with a lot of text

# %%
df3.describe
# Out:
# <bound method NDFrame.describe of                              Unnamed: 0     DBN  \
# 0               01M01532013All Students  01M015
# 1               01M01532014All Students  01M015
# 2               01M01532015All Students  01M015
# 3               01M01532016All Students  01M015
# 4               01M01532017All Students  01M015
# ...                                 ...     ...
# 32601  32K562All Grades2015All Students  32K562
# 32602  32K562All Grades2016All Students  32K562
# 32603  32K562All Grades2017All Students  32K562
# 32604  32K562All Grades2018All Students  32K562
# 32605  32K562All Grades2019All Students  32K562
#
#                                          School Name       Grade  Year  \
# 0                          P.S. 015 ROBERTO CLEMENTE           3  2013
# 1                          P.S. 015 ROBERTO CLEMENTE           3  2014
# 2                          P.S. 015 ROBERTO CLEMENTE           3  2015
# ...

# %%
df3.head()
# Out:
#                 Unnamed: 0     DBN                School Name Grade  Year  \
# 0  01M01532013All Students  01M015  P.S. 015 ROBERTO CLEMENTE     3  2013
# 1  01M01532014All Students  01M015  P.S. 015 ROBERTO CLEMENTE     3  2014
# 2  01M01532015All Students  01M015  P.S. 015 ROBERTO CLEMENTE     3  2015
# 3  01M01532016All Students  01M015  P.S. 015 ROBERTO CLEMENTE     3  2016
# 4  01M01532017All Students  01M015  P.S. 015 ROBERTO CLEMENTE     3  2017
#
#        Category  Number Tested Mean Scale Score # Level 1  % Level 1  \
# 0  All Students             27       277.777771        16  59.259258
# 1  All Students             18       286.388886         6  33.333332
# 2  All Students             17       279.588226        10  58.823528
# 3  All Students             21       274.809509        13  61.904762
# 4  All Students             29       301.551727         8  27.586206
#
#   # Level 2  % Level 2 # Level 3  % Level 3 # Level 4  % Level 4 # Level 3+4  \
# ...

# %%
df3.tail()

# %% [markdown]
# The final dataset we are going to work with is actually a data dictionary for the "SARS-CoV-2 concentrations measured in NYC Wastewater".  While this is not a traditional dataset, I could imagine instances that might require you to reshape and potentially join this to another dataset

# %%
df4 = pd.read_excel('https://data.cityofnewyork.us/api/views/f7dc-2q9f/files/da3e4ade-202a-4191-9bde-7ecaf40b7efe?download=true&filename=COVID19_SARS-CoV-2%20data%20on%20wastewater%20samples%20_METADATA_V02.00.xlsx')

# %% [markdown]
# When we print the column names can see that the most of the columns are unnamed, something that we will have to fix.

# %%
print(df4.columns)
# Out:
# Index(['Data Dictionary - Column Information', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3'],
#       dtype='object')
#                 Data Dictionary - Column Information  \
# 5                                  WRRF Abbreviation
# 6  Concentration SARS-CoV-2 gene target (N1 Copie...
# 7  Per capita SARS-CoV-2 load\n(N1 copies per day...
# 8                                         Annotation
# 9                       Population Served, estimated
#
#                                           Unnamed: 1  \
# 5                                  WRRF Abbreviation
# 6  Concentration of the N1 target of SARS-CoV2 ge...
# 7  Normalized  SARS-CoV-2 N gene concentration (t...
# 8                      Notes on sampling and testing
# 9                            Population of sewershed
#
#                               Unnamed: 2  \
# 5  Two letter abbreviation for WRRF name
# 6                                    NaN
# 7                                    NaN
# ...

# %% [markdown]
# In this instance, we can preview the whole dataframe when we view it.

# %%
df4
# Out:
#                 Data Dictionary - Column Information  \
# 0                                        Column Name
# 1                                                NaN
# 2                                        Sample Date
# 3                                          Test Date
# 4                                          WRRF Name
# 5                                  WRRF Abbreviation
# 6  Concentration SARS-CoV-2 gene target (N1 Copie...
# 7  Per capita SARS-CoV-2 load\n(N1 copies per day...
# 8                                         Annotation
# 9                       Population Served, estimated
#
#                                           Unnamed: 1  \
# 0                                 Column Description
# 1                                                NaN
# 2                          Date sample was collected
# 3                           Date sample was analyzed
# 4  Wastewater Resource Recovery Facility (waste w...
# 5                                  WRRF Abbreviation
# ...

# %% [markdown]
# The dimensions of this df is 10 X 4

# %%
df4.shape
# Out:
# (10, 4)

# %% [markdown]
# The data types are objects?

# %%
df4.dtypes
# Out:
# Data Dictionary - Column Information    object
# Unnamed: 1                              object
# Unnamed: 2                              object
# Unnamed: 3                              object
# dtype: object

# %% [markdown]
# This is interesting, because of the structure of this dataframe the describe method is not the best way to look at this.

# %%
df4.describe
# Out:
# <bound method NDFrame.describe of                 Data Dictionary - Column Information  \
# 0                                        Column Name
# 1                                                NaN
# 2                                        Sample Date
# 3                                          Test Date
# 4                                          WRRF Name
# 5                                  WRRF Abbreviation
# 6  Concentration SARS-CoV-2 gene target (N1 Copie...
# 7  Per capita SARS-CoV-2 load\n(N1 copies per day...
# 8                                         Annotation
# 9                       Population Served, estimated
#
#                                           Unnamed: 1  \
# 0                                 Column Description
# 1                                                NaN
# 2                          Date sample was collected
# 3                           Date sample was analyzed
# 4  Wastewater Resource Recovery Facility (waste w...
# ...

# %% [markdown]
# This shows us the top 5 rows.  We see the unnamed columns and some missing values.

# %%
df4.head()
# Out:
#   Data Dictionary - Column Information  \
# 0                          Column Name
# 1                                  NaN
# 2                          Sample Date
# 3                            Test Date
# 4                            WRRF Name
#
#                                           Unnamed: 1  \
# 0                                 Column Description
# 1                                                NaN
# 2                          Date sample was collected
# 3                           Date sample was analyzed
# 4  Wastewater Resource Recovery Facility (waste w...
#
#                                       Unnamed: 2  \
# 0             Term, Acronym, or Code Definitions
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4  WRRF is wastewater resource recovery facility
#
#                                           Unnamed: 3
# ...

# %% [markdown]
# The tail is less helpful, we still have the unnamed columns but we don't see that the first row is actually column names.

# %%
df4.tail()
# Out:
#                 Data Dictionary - Column Information  \
# 5                                  WRRF Abbreviation
# 6  Concentration SARS-CoV-2 gene target (N1 Copie...
# 7  Per capita SARS-CoV-2 load\n(N1 copies per day...
# 8                                         Annotation
# 9                       Population Served, estimated
#
#                                           Unnamed: 1  \
# 5                                  WRRF Abbreviation
# 6  Concentration of the N1 target of SARS-CoV2 ge...
# 7  Normalized  SARS-CoV-2 N gene concentration (t...
# 8                      Notes on sampling and testing
# 9                            Population of sewershed
#
#                               Unnamed: 2  \
# 5  Two letter abbreviation for WRRF name
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
#
#                                           Unnamed: 3
# ...
